# %% [markdown]
# ## Import modules and tools

# %%
import scanpy as sc
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from os import path
from os import listdir
import datetime, time

# %%
# costome codes

import ma_codes as codes
from ma_codes import mysize, mymap

# %% [markdown]
# #### Define a nice colour map for gene expression

# %%
from matplotlib import colors
colorsComb = np.vstack([plt.cm.Reds(np.linspace(0, 1, 128)), plt.cm.Greys_r(np.linspace(0.7, 0.8, 0))])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
plt.rcParams['savefig.dpi'] = 200 #图片像素
plt.rcParams['figure.dpi'] = 200 #分辨率

# %%
import pandas as pd
#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', None)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)

# %% [markdown]
# #### set timestamp function

# %%
def timestamp():
    ts = time.time()
    st = datetime.datetime.fromtimFestamp(ts).strftime('%d-%m-%Y %H:%M:%S')
    return st

# %% [markdown]
# #### workdirectory

# %%
folder = "/media/qianjianghu/SG_QJData/DataAnlysis/Jupyter/WNT_PCLS/"

# %% [markdown]
# #### scanpy setting and version

# %%
sc.settings.verbosity = 4             # verbosity: 0=’error’, 1=’warning’, 2=’info’, 3=’hint’, 4=more details, 5=even more details, etc.
sc.logging.print_header()
Obj_folder = '/media/qianjianghu/SG_QJData/DataAnlysis/Jupyter/WNT_PCLS/Object_folder/'  # the file that will store the analysis results
# Out:
# scanpy==1.6.0 anndata==0.7.5 umap==0.4.6 numpy==1.18.5 scipy==1.5.2 pandas==1.1.5 scikit-learn==0.23.2 statsmodels==0.12.0 python-igraph==0.8.3 louvain==0.6.1 leidenalg==0.8.3

# %% [markdown]
# ## Reload adata

# %%
EPITHELIAL = sc.read(Obj_folder + "/PP5_EPITHELIAL_cluster_WNT_PCLS.h5ad")

# %% [markdown]
# ## ranking genes each cluster

# %%
EPITHELIAL
# Out:
# AnnData object with n_obs × n_vars = 4343 × 23558
#     obs: 'project', 'genome', 'groups', 'treatment', 'treated_days', 'estimated_cells', 'identifier', 'doublet_scores', 'predicted_doublets', 'n_counts', 'n_genes', 'percent.mito', 'size_factors', 'S_score', 'G2M_score', 'phase', 'louvain', 'leiden', 'leiden_0.3', 'TYPE', 'Epi_leiden_2', 'cell_type', 'Epi_leiden_4', 'Epi_leiden_5', 'Epi_leiden_6', 'cell_type_new', 'cluster'
#     var: 'n_cells', 'highly_variable', 'mean', 'std'
#     uns: 'Epi_leiden_2_colors', 'Epi_leiden_4_colors', 'Epi_leiden_5_colors', 'Epi_leiden_6_colors', 'TYPE_colors', 'cell_type_colors', 'cell_type_new_colors', 'cluster_colors', 'groups_colors', 'identifier_colors', 'leiden', 'leiden_colors', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_cluster', 'rank_genes_groups', 'treated_days_colors', 'treatment_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
#Calculate marker genes
sc.tl.rank_genes_groups(EPITHELIAL, groupby='cell_type_new', key_added='rank_genes_cluster_cell_type', n_genes=500)
# Out:
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# ranking genes
#     consider 'cell_type_new' groups:
#     with sizes: [403 346 329 325 309 174 232 210 203 185 181 180 161 160 121 110 102  92
#   89  85  65  62  60  27  17 115]
#     finished: added to `.uns['rank_genes_cluster_cell_type']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:07)

# %%
result_folder = '/media/qianjianghu/SG_QJData/DataAnlysis/Jupyter/WNT_PCLS/results/'

# %% [markdown]
# #### export and layout clusters horizontally

# %%
####
#### layout clusters horizontally
####

result = EPITHELIAL.uns['rank_genes_cluster_cell_type']
groups = result['names'].dtype.names
cluster_marker = pd.DataFrame(
    {'Cluster'+group + '_' + key: result[key][group]
    for group in groups for key in ['names', 'pvals','pvals_adj', 'logfoldchanges']})

# %%
cluster_marker.head()
# Out:
#   ClusterC0_names  ClusterC0_pvals  ClusterC0_pvals_adj  \
# 0         mt-Rnr2    1.815628e-265        4.277256e-261
# 1          Malat1     4.415912e-83         3.467668e-80
# 2         mt-Rnr1     3.012854e-36         2.628771e-34
# 3          Gm8995     4.782000e-26         2.213248e-24
# 4          Akap12     1.176642e-17         2.828503e-16
#
#    ClusterC0_logfoldchanges ClusterC1_names  ClusterC1_pvals  \
# 0                  1.852911         mt-Rnr2    1.077940e-204
# 1                  1.667595          Malat1    9.391336e-128
# 2                  1.311597         mt-Rnr1     4.659801e-65
# 3                  3.179454          Akap12     8.698404e-32
# 4                  2.696359          Gm8995     6.730212e-31
#
#    ClusterC1_pvals_adj  ClusterC1_logfoldchanges ClusterC2_Krt8_ADI_names  \
# 0        2.539411e-200                  1.925961                   Tmsb4x
# 1        5.531027e-124                  1.999551                     Krt8
# 2         2.335651e-62                  1.702771                    Krt18
# 3         8.776804e-30                  3.666530                     Actb
# 4         6.497965e-29                  3.523536                     Myl6
#
#    ClusterC2_Krt8_ADI_pvals  ClusterC2_Krt8_ADI_pvals_adj  \
# 0             1.686682e-100                  5.676408e-97
# 1              1.954261e-70                  1.705129e-67
# 2              2.102818e-67                  1.376061e-64
# 3              1.745869e-66                  1.082347e-63
# 4              3.278309e-64                  1.796056e-61
#
#    ClusterC2_Krt8_ADI_logfoldchanges ClusterC3_ciliated_names  \
# 0                           2.237518                    Nupr1
# 1                           2.396628                     Fth1
# 2                           2.297471                  Gm19935
# 3                           1.728962                    Tppp3
# 4                           2.306008                      Mt1
#
#    ClusterC3_ciliated_pvals  ClusterC3_ciliated_pvals_adj  \
# 0              8.588919e-68                  3.372296e-64
# 1              1.508342e-47                  1.776676e-44
# 2              5.330207e-41                  3.587686e-38
# 3              3.030167e-30                  8.705449e-28
# 4              2.450559e-26                  5.020022e-24
#
#    ClusterC3_ciliated_logfoldchanges ClusterC4_basal_names  \
# 0                           2.806788               mt-Rnr2
# 1                           1.326333                 Rps12
# 2                           3.263643                 Rps14
# 3                           2.350983                Tmsb4x
# 4                           1.763277                 Rpl12
#
#    ClusterC4_basal_pvals  ClusterC4_basal_pvals_adj  \
# 0           3.511470e-85               1.034040e-81
# 1           1.221775e-31               8.591810e-30
# 2           5.882500e-30               3.580877e-28
# 3           7.015126e-30               4.248389e-28
# 4           8.695928e-28               4.396109e-26
#
#    ClusterC4_basal_logfoldchanges ClusterC5_names  ClusterC5_pvals  \
# 0                        1.356172             Clu     4.028291e-38
# 1                        1.853010           Cldn4     2.435506e-24
# 2                        1.506070          Phldb2     1.967725e-23
# 3                        1.460171            Tpm1     8.194889e-24
# 4                        1.707105           Krt19     7.799827e-21
#
#    ClusterC5_pvals_adj  ClusterC5_logfoldchanges ClusterC6_ciliated_names  \
# 0         1.216647e-35                  2.546970                  Tmem212
# 1         3.984420e-22                  2.438120                  Ccdc153
# 2         2.897229e-21                  2.228033                    Foxj1
# 3         1.245517e-21                  1.383089                    Nupr1
# 4         9.096452e-19                  1.492403                    Tppp3
#
#    ClusterC6_ciliated_pvals  ClusterC6_ciliated_pvals_adj  \
# 0              1.036238e-94                  4.068617e-91
# 1              1.096727e-87                  2.583669e-84
# 2              8.701040e-89                  2.277545e-85
# 3              2.454855e-85                  5.257407e-82
# 4              2.004995e-82                  3.633359e-79
#
#    ClusterC6_ciliated_logfoldchanges ClusterC7_names  ClusterC7_pvals  \
# 0                           4.224972             Esd     2.414016e-35
# 1                           3.873407             Ncl     7.220534e-35
# 2                           3.068495           Plin2     1.450943e-31
# 3                           2.893992          Lgals3     1.391018e-31
# 4                           3.154677          Akr1b8     2.898153e-29
#
#    ClusterC7_pvals_adj  ClusterC7_logfoldchanges ClusterC8_basal_names  \
# 0         1.263764e-32                  1.677655                  Fth1
# 1         3.697855e-32                  1.623817                 Gsta1
# 2         5.425605e-29                  2.197880                 Gsta4
# 3         5.285421e-29                  1.652206               Scgb1a1
# 4         9.868305e-27                  1.887856                   Esd
#
#    ClusterC8_basal_pvals  ClusterC8_basal_pvals_adj  \
# 0           4.946481e-42               1.942153e-39
# 1           1.250992e-19               6.806204e-18
# 2           1.228262e-18               6.053431e-17
# 3           7.362790e-18               3.354983e-16
# 4           1.317758e-16               5.031399e-15
#
#    ClusterC8_basal_logfoldchanges ClusterC9_names  ClusterC9_pvals  \
# 0                        1.656945             Clu     1.914625e-29
# 1                        3.938409          Tmsb4x     2.316111e-29
# 2                        2.249505            Krt7     3.727022e-22
# 3                        2.482672            Actb     8.685873e-22
# 4                        1.638964            Krt8     8.268221e-21
#
#    ClusterC9_pvals_adj  ClusterC9_logfoldchanges ClusterC10_ciliated_names  \
# 0         1.804190e-27                  2.550858                      Fth1
# 1         2.165196e-27                  1.533536                    S100a6
# 2         1.836845e-20                  1.571898                     Gsta4
# 3         4.059956e-20                  1.245195                    Akr1b8
# 4         3.478263e-19                  1.597375                       Esd
#
#    ClusterC10_ciliated_pvals  ClusterC10_ciliated_pvals_adj  \
# 0              2.124783e-100                   5.561736e-97
# 1               2.306375e-94                   4.527799e-91
# 2               2.346314e-71                   2.909183e-68
# 3               1.701557e-64                   1.670220e-61
# 4               1.948097e-67                   2.185394e-64
#
#    ClusterC10_ciliated_logfoldchanges ClusterC11_Club_names  \
# 0                            1.985962                   Trf
# 1                            2.207868                    Hp
# 2                            3.272163                  Npc2
# 3                            3.052373              Selenbp1
# 4                            2.242618                   Bsg
#
#    ClusterC11_Club_pvals  ClusterC11_Club_pvals_adj  \
# 0           4.815077e-58               5.401599e-55
# 1           4.724282e-53               3.974808e-50
# 2           4.076850e-50               2.667845e-47
# 3           5.969136e-45               2.991934e-42
# 4           7.068337e-37               2.107796e-34
#
#    ClusterC11_Club_logfoldchanges ClusterC12_AT2_names  ClusterC12_AT2_pvals  \
# 0                        5.199295                Sftpc         2.364060e-257
# 1                        4.158727               Sftpa1         3.300357e-157
# 2                        2.922739                 Lyz2         1.332946e-118
# 3                        3.599046                Sftpb         2.021462e-104
# 4                        2.831198                Sftpd          3.675907e-89
#
#    ClusterC12_AT2_pvals_adj  ClusterC12_AT2_logfoldchanges  \
# 0             5.569252e-253                       9.878492
# 1             5.553559e-154                       8.191777
# 2             1.256062e-115                       7.439246
# 3             1.360618e-101                       5.252878
# 4              1.804104e-86                       4.704707
#
#   ClusterC13_Club_names  ClusterC13_Club_pvals  ClusterC13_Club_pvals_adj  \
# 0              Selenbp1          2.759313e-115              1.625098e-111
# 1                   Trf           1.294740e-99               3.389055e-96
# 2                  Npc2          1.136365e-110              5.354098e-107
# 3                    Hp           4.150324e-98               8.888486e-95
# 4                   Bsg           1.539349e-98               3.626398e-95
#
#    ClusterC13_Club_logfoldchanges ClusterC14_ciliated_names  \
# 0                        4.938071                   Sec14l3
# 1                        6.348213                   Ccdc153
# 2                        3.719419                     Tppp3
# 3                        5.589223                      Cbr2
# 4                        3.859809                     Calm1
#
#    ClusterC14_ciliated_pvals  ClusterC14_ciliated_pvals_adj  \
# 0               5.204444e-78                   6.811460e-75
# 1               1.982682e-65                   1.415394e-62
# 2               1.109977e-57                   5.942920e-55
# 3               1.132550e-59                   6.507469e-57
# 4               1.723140e-46                   6.765622e-44
#
#    ClusterC14_ciliated_logfoldchanges ClusterC15_ciliated_names  \
# 0                            5.871947                    Tm4sf1
# 1                            4.681512                       Clu
# 2                            3.912758                     Nupr1
# 3                            3.147283                    Prxl2a
# 4                            1.764807             1810037I17Rik
#
#    ClusterC15_ciliated_pvals  ClusterC15_ciliated_pvals_adj  \
# 0               8.191721e-31                   2.412257e-27
# 1               1.850819e-26                   3.353969e-23
# 2               9.688447e-24                   1.201265e-20
# 3               2.159813e-18                   1.541845e-15
# 4               2.043471e-17                   1.174149e-14
#
#    ClusterC15_ciliated_logfoldchanges ClusterC16_names  ClusterC16_pvals  \
# 0                            2.738625           Hnrnpc          0.000001
# 1                            2.449037         Ppp1r15a          0.000016
# 2                            2.241548           Ptpn14          0.000064
# 3                            2.086487           Luc7l3          0.000081
# 4                            1.574555             Brd2          0.000110
#
#    ClusterC16_pvals_adj  ClusterC16_logfoldchanges ClusterC17_names  \
# 0              0.000011                   1.679872          Ccdc153
# 1              0.000137                   2.089035            Foxj1
# 2              0.000499                   2.430466           Tuba1a
# 3              0.000621                   1.515287            Tppp3
# 4              0.000810                   1.366851            Rsph1
#
#    ClusterC17_pvals  ClusterC17_pvals_adj  ClusterC17_logfoldchanges  \
# 0      1.120141e-10          3.340290e-09                   2.646315
# 1      4.523185e-10          1.223389e-08                   2.131730
# 2      1.985523e-08          3.997859e-07                   1.683689
# 3      5.488434e-08          1.022916e-06                   1.935181
# 4      6.471796e-08          1.193912e-06                   1.992964
#
#   ClusterC18_AT2_names  ClusterC18_AT2_pvals  ClusterC18_AT2_pvals_adj  \
# 0                Sftpc          2.947855e-56              7.548430e-54
# 1               Sftpa1          5.172610e-46              7.761551e-44
# 2                 Lyz2          4.331646e-38              4.576005e-36
# 3                 Npc2          2.335867e-31              1.725027e-29
# 4                Hspa5          9.071827e-30              6.158908e-28
#
#    ClusterC18_AT2_logfoldchanges ClusterC19_club_names  ClusterC19_club_pvals  \
# 0                       8.415749                 Wfdc2           1.140740e-34
# 1                       6.467368                  Cbr2           1.463733e-31
# 2                       5.938001                    Cp           2.411183e-25
# 3                       2.975470                   Trf           4.729882e-25
# 4                       3.258835              Selenbp1           9.142711e-25
#
#    ClusterC19_club_pvals_adj  ClusterC19_club_logfoldchanges  \
# 0               2.465463e-32                        2.918976
# 1               2.758611e-29                        3.809022
# 2               3.138267e-23                        4.187604
# 3               6.088883e-23                        4.996415
# 4               1.151786e-22                        3.112191
#
#   ClusterC20_club_names  ClusterC20_club_pvals  ClusterC20_club_pvals_adj  \
# 0               Scgb1a1           5.703205e-61               1.119634e-57
# 1                  Cbr2           1.495342e-47               1.560473e-44
# 2                Cyp2f2           1.498875e-36               7.846775e-34
# 3                    Hp           2.918660e-33               1.322265e-30
# 4               Aldh1a1           5.117317e-22               7.581997e-20
#
#    ClusterC20_club_logfoldchanges ClusterC21_krt8High_names  \
# 0                        7.746153                      Krt8
# 1                        5.006602                     Krt18
# 2                        6.394827                        F3
# 3                        4.584358                      Tpm1
# 4                        3.962150                      Rtn4
#
#    ClusterC21_krt8High_pvals  ClusterC21_krt8High_pvals_adj  \
# 0               1.363841e-37                   5.841704e-35
# 1               3.743995e-27                   8.480868e-25
# 2               2.282736e-24                   4.336830e-22
# 3               3.206119e-22                   5.173270e-20
# 4               1.377903e-20                   1.844354e-18
#
#    ClusterC21_krt8High_logfoldchanges ClusterC22_krt8high_names  \
# 0                            3.100900                   mt-Rnr2
# 1                            2.745305                   Gm42418
# 2                            4.096493                     Lars2
# 3                            2.164733                   Gm26917
# 4                            2.886471                     Rn7sk
#
#    ClusterC22_krt8high_pvals  ClusterC22_krt8high_pvals_adj  \
# 0               2.797602e-34                   6.046413e-33
# 1               4.994612e-20                   5.565897e-19
# 2               4.290355e-19                   4.552801e-18
# 3               3.089036e-18                   3.146196e-17
# 4               3.930607e-17                   3.759531e-16
#
#    ClusterC22_krt8high_logfoldchanges ClusterC23_neuroendocrine_names  \
# 0                            2.024664                          Resp18
# 1                            4.490399                            Scg2
# 2                            7.607462                           Ptprn
# 3                           10.494974                           Celf4
# 4                            9.354913                            Car8
#
#    ClusterC23_neuroendocrine_pvals  ClusterC23_neuroendocrine_pvals_adj  \
# 0                         0.000021                             0.000121
# 1                         0.000026                             0.000148
# 2                         0.000042                             0.000235
# 3                         0.000107                             0.000568
# 4                         0.000153                             0.000791
#
#    ClusterC23_neuroendocrine_logfoldchanges ClusterC24_AT1_names  \
# 0                                 11.269704                 Ager
# 1                                 30.544918                Sparc
# 2                                  7.846186               Cldn18
# 3                                  5.404445               Cavin2
# 4                                  3.292826                 Emp2
#
#    ClusterC24_AT1_pvals  ClusterC24_AT1_pvals_adj  \
# 0          6.861547e-14              3.195183e-13
# 1          5.026762e-09              1.859034e-08
# 2          1.060037e-06              3.459255e-06
# 3          3.572131e-06              1.132906e-05
# 4          4.613112e-06              1.449589e-05
#
#    ClusterC24_AT1_logfoldchanges ClusterC25_Krt8_ADI_2_names  \
# 0                       7.902991                         Clu
# 1                       5.913456                        Tpm1
# 2                       4.996635                       Cldn4
# 3                       4.882470                         Fn1
# 4                       4.424956                       Krt19
#
#    ClusterC25_Krt8_ADI_2_pvals  ClusterC25_Krt8_ADI_2_pvals_adj  \
# 0                 3.478355e-39                     7.730481e-37
# 1                 3.305964e-28                     4.554497e-26
# 2                 2.728981e-26                     3.365934e-24
# 3                 6.992458e-26                     8.427341e-24
# 4                 1.351353e-24                     1.515961e-22
#
#    ClusterC25_Krt8_ADI_2_logfoldchanges
# 0                              2.777132
# 1                              2.111871
# 2                              3.119922
# 3                              3.885510
# 4                              1.850168

# %%
cluster_marker.tail()
# Out:
#     ClusterC0_names  ClusterC0_pvals  ClusterC0_pvals_adj  \
# 495            Arnt         0.032566             0.093396
# 496            Chd1         0.032681             0.093650
# 497            Usf3         0.033133             0.094714
# 498            Inmt         0.033362             0.095234
# 499           Csf3r         0.033588             0.095739
#
#      ClusterC0_logfoldchanges ClusterC1_names  ClusterC1_pvals  \
# 495                  1.832983         Tsc22d4         0.009018
# 496                  0.728637          Phf11b         0.009076
# 497                  1.440059           Bod1l         0.009091
# 498                  3.313454         Gm42870         0.009218
# 499                  5.195017           Slfn3         0.009271
#
#      ClusterC1_pvals_adj  ClusterC1_logfoldchanges ClusterC2_Krt8_ADI_names  \
# 495             0.036542                  1.184173                    Eif3b
# 496             0.036756                  3.905086                    Dhrs1
# 497             0.036803                  0.748075                     Amot
# 498             0.037230                  3.294126                    Pdcd5
# 499             0.037404                  4.038545                     Mlf2
#
#      ClusterC2_Krt8_ADI_pvals  ClusterC2_Krt8_ADI_pvals_adj  \
# 495                  0.041997                      0.095150
# 496                  0.042406                      0.095947
# 497                  0.042925                      0.096904
# 498                  0.042907                      0.096876
# 499                  0.043209                      0.097445
#
#      ClusterC2_Krt8_ADI_logfoldchanges ClusterC3_ciliated_names  \
# 495                           0.447516            C230072F16Rik
# 496                           0.906173                   Klhl12
# 497                           1.798419                   Ndufv2
# 498                           0.629606            1700016J18Rik
# 499                           0.651240                  Ccdc148
#
#      ClusterC3_ciliated_pvals  ClusterC3_ciliated_pvals_adj  \
# 495                  0.041947                      0.128004
# 496                  0.043011                      0.130405
# 497                  0.043287                      0.131024
# 498                  0.043857                      0.132392
# 499                  0.043884                      0.132455
#
#      ClusterC3_ciliated_logfoldchanges ClusterC4_basal_names  \
# 495                           1.664326                 Tomm6
# 496                           1.282985                  Hypk
# 497                           0.504476                  Bex1
# 498                           2.724003                  Mycl
# 499                           1.885486                 Dock4
#
#      ClusterC4_basal_pvals  ClusterC4_basal_pvals_adj  \
# 495               0.290014                   0.418366
# 496               0.290728                   0.418366
# 497               0.291479                   0.418366
# 498               0.294630                   0.418366
# 499               0.296698                   0.418366
#
#      ClusterC4_basal_logfoldchanges ClusterC5_names  ClusterC5_pvals  \
# 495                        1.381117            Bin1         0.000780
# 496                        0.531313         Irf2bpl         0.000788
# 497                        0.853940          Znhit6         0.000804
# 498                        1.096514           Psmd4         0.000795
# 499                        1.409159           Ctbp2         0.000808
#
#      ClusterC5_pvals_adj  ClusterC5_logfoldchanges ClusterC6_ciliated_names  \
# 495             0.009347                  1.074733                   mt-Nd1
# 496             0.009419                  1.268461            2010001K21Rik
# 497             0.009586                  1.699784                  Ccdc114
# 498             0.009498                  0.662577                   Lrrc36
# 499             0.009621                  1.203114                     Amn1
#
#      ClusterC6_ciliated_pvals  ClusterC6_ciliated_pvals_adj  \
# 495              4.172419e-13                  1.136345e-11
# 496              6.155210e-13                  1.651531e-11
# 497              6.242316e-13                  1.672998e-11
# 498              6.506072e-13                  1.741705e-11
# 499              6.633786e-13                  1.771868e-11
#
#      ClusterC6_ciliated_logfoldchanges ClusterC7_names  ClusterC7_pvals  \
# 495                           0.875670            Dstn         0.000002
# 496                           3.249036           Clic4         0.000002
# 497                           3.007859            Uba1         0.000002
# 498                           4.005573          Mrpl33         0.000003
# 499                           2.341094        Slc25a51         0.000003
#
#      ClusterC7_pvals_adj  ClusterC7_logfoldchanges ClusterC8_basal_names  \
# 495             0.000046                  0.791598                 Abce1
# 496             0.000045                  0.806389                  Capg
# 497             0.000049                  0.919785               Gm10639
# 498             0.000051                  0.897586                Gm7868
# 499             0.000052                  1.186127                Cd3eap
#
#      ClusterC8_basal_pvals  ClusterC8_basal_pvals_adj  \
# 495               0.183354                   0.359744
# 496               0.183416                   0.359775
# 497               0.183523                   0.359927
# 498               0.183681                   0.360175
# 499               0.184645                   0.361495
#
#      ClusterC8_basal_logfoldchanges ClusterC9_names  ClusterC9_pvals  \
# 495                        0.678382          Pard3b         0.153584
# 496                        0.586780           Lzts2         0.153567
# 497                        2.500020         Epb41l5         0.154985
# 498                        4.907669           Psmc2         0.155103
# 499                        0.731700        Smarcal1         0.155577
#
#      ClusterC9_pvals_adj  ClusterC9_logfoldchanges ClusterC10_ciliated_names  \
# 495             0.315361                  1.434699                      Arl6
# 496             0.315361                  0.951293                     Cspp1
# 497             0.317628                  0.882477                      Pygl
# 498             0.317843                  0.486043                     Appl2
# 499             0.318582                  1.405989                      Mall
#
#      ClusterC10_ciliated_pvals  ClusterC10_ciliated_pvals_adj  \
# 495               3.281982e-07                       0.000007
# 496               3.196499e-07                       0.000007
# 497               3.230626e-07                       0.000007
# 498               3.208477e-07                       0.000007
# 499               3.496696e-07                       0.000007
#
#      ClusterC10_ciliated_logfoldchanges ClusterC11_Club_names  \
# 495                            1.922322                 Lman2
# 496                            1.274906                 Fgfr1
# 497                            1.645297                  Tbx1
# 498                            0.992601                 Rbpjl
# 499                            2.026695                 Vamp3
#
#      ClusterC11_Club_pvals  ClusterC11_Club_pvals_adj  \
# 495               0.119028                   0.302619
# 496               0.119565                   0.303621
# 497               0.119818                   0.304134
# 498               0.119860                   0.304209
# 499               0.119962                   0.304436
#
#      ClusterC11_Club_logfoldchanges ClusterC12_AT2_names  \
# 495                        0.715545               Rpl36a
# 496                        1.901690                 Npr1
# 497                        1.266537              Fam184a
# 498                        1.359751               Dhcr24
# 499                        0.753128                Ddx17
#
#      ClusterC12_AT2_pvals  ClusterC12_AT2_pvals_adj  \
# 495              0.000952                  0.006260
# 496              0.000990                  0.006484
# 497              0.000993                  0.006501
# 498              0.000993                  0.006501
# 499              0.000997                  0.006525
#
#      ClusterC12_AT2_logfoldchanges ClusterC13_Club_names  \
# 495                       0.733407              Atxn7l3b
# 496                       2.954659                 Wdr45
# 497                       2.387876                  Eny2
# 498                       1.106378                 Capzb
# 499                       1.062509                   Mif
#
#      ClusterC13_Club_pvals  ClusterC13_Club_pvals_adj  \
# 495           3.212953e-07                   0.000006
# 496           3.437866e-07                   0.000006
# 497           3.481479e-07                   0.000006
# 498           3.352514e-07                   0.000006
# 499           3.444627e-07                   0.000006
#
#      ClusterC13_Club_logfoldchanges ClusterC14_ciliated_names  \
# 495                        1.100454                   Selenok
# 496                        2.441287                      Vapa
# 497                        1.254556                     Ift27
# 498                        0.809898                     Wnt11
# 499                        0.849060                    Scnn1a
#
#      ClusterC14_ciliated_pvals  ClusterC14_ciliated_pvals_adj  \
# 495                   0.000007                       0.000090
# 496                   0.000007                       0.000090
# 497                   0.000007                       0.000093
# 498                   0.000008                       0.000096
# 499                   0.000008                       0.000095
#
#      ClusterC14_ciliated_logfoldchanges ClusterC15_ciliated_names  \
# 495                            1.407580                      Drc7
# 496                            1.180699                   Phf20l1
# 497                            1.850911                      Ktn1
# 498                            2.279153                     Pdcd6
# 499                            1.751308                      Mea1
#
#      ClusterC15_ciliated_pvals  ClusterC15_ciliated_pvals_adj  \
# 495                   0.000508                       0.008692
# 496                   0.000509                       0.008704
# 497                   0.000511                       0.008717
# 498                   0.000514                       0.008753
# 499                   0.000511                       0.008719
#
#      ClusterC15_ciliated_logfoldchanges ClusterC16_names  ClusterC16_pvals  \
# 495                            1.459904            Mgat2          0.096119
# 496                            0.880578            Jmjd8          0.096458
# 497                            0.796018             Msl1          0.096596
# 498                            0.932989        Rpl19-ps9          0.097305
# 499                            0.898620           Pdcd11          0.097576
#
#      ClusterC16_pvals_adj  ClusterC16_logfoldchanges ClusterC17_names  \
# 495              0.257725                   1.133836          Psmc3ip
# 496              0.258222                   1.893682          Fam229b
# 497              0.258534                   0.893684            Snhg1
# 498              0.259989                  23.814152           Ndufc2
# 499              0.260565                   1.070554       AC149090.1
#
#      ClusterC17_pvals  ClusterC17_pvals_adj  ClusterC17_logfoldchanges  \
# 495          0.080204              0.243538                   1.330889
# 496          0.080263              0.243538                   2.349549
# 497          0.080293              0.243597                   0.903597
# 498          0.080812              0.244642                   0.622529
# 499          0.080881              0.244785                   1.103312
#
#     ClusterC18_AT2_names  ClusterC18_AT2_pvals  ClusterC18_AT2_pvals_adj  \
# 495                 Sltm              0.002328                  0.010999
# 496                Ccng2              0.002362                  0.011141
# 497                H2afj              0.002346                  0.011074
# 498                Prdm2              0.002384                  0.011230
# 499                  Mme              0.002453                  0.011507
#
#      ClusterC18_AT2_logfoldchanges ClusterC19_club_names  \
# 495                       1.111825                 Abcd3
# 496                       3.311383                 Srsf5
# 497                       0.809327                  Pygb
# 498                       1.931939                  Csad
# 499                       3.370503                 Rbms3
#
#      ClusterC19_club_pvals  ClusterC19_club_pvals_adj  \
# 495               0.007260                   0.047893
# 496               0.007309                   0.048147
# 497               0.007455                   0.048877
# 498               0.007459                   0.048892
# 499               0.007580                   0.049545
#
#      ClusterC19_club_logfoldchanges ClusterC20_club_names  \
# 495                        0.967750               Wdr83os
# 496                        0.770297                 Puf60
# 497                        1.936892               Mir22hg
# 498                        1.603817                 Palmd
# 499                        2.275038               Chordc1
#
#      ClusterC20_club_pvals  ClusterC20_club_pvals_adj  \
# 495               0.052565                   0.186045
# 496               0.052655                   0.186280
# 497               0.052671                   0.186308
# 498               0.053011                   0.187148
# 499               0.053095                   0.187389
#
#      ClusterC20_club_logfoldchanges ClusterC21_krt8High_names  \
# 495                        1.388251                     Cpsf6
# 496                        1.061881                     Runx1
# 497                        1.465283                    Rnf114
# 498                        2.246486                      Sfr1
# 499                        1.264280                   Trmt10c
#
#      ClusterC21_krt8High_pvals  ClusterC21_krt8High_pvals_adj  \
# 495                   0.000317                       0.002985
# 496                   0.000318                       0.002999
# 497                   0.000324                       0.003042
# 498                   0.000331                       0.003101
# 499                   0.000341                       0.003183
#
#      ClusterC21_krt8High_logfoldchanges ClusterC22_krt8high_names  \
# 495                            2.129710                    Hmg20b
# 496                            1.317189                      Dpp3
# 497                            1.419659                    Ptprn2
# 498                            1.112814                     Ephb3
# 499                            2.650565                     Ep400
#
#      ClusterC22_krt8high_pvals  ClusterC22_krt8high_pvals_adj  \
# 495                   0.183082                       0.328064
# 496                   0.183139                       0.328115
# 497                   0.183585                       0.328689
# 498                   0.183993                       0.329190
# 499                   0.184004                       0.329190
#
#      ClusterC22_krt8high_logfoldchanges ClusterC23_neuroendocrine_names  \
# 495                            1.248404                             Oga
# 496                            1.063566                            Crb3
# 497                            5.569147                           Ncam1
# 498                            2.153585                         Hoxb3os
# 499                            1.200516                         Rasgrf1
#
#      ClusterC23_neuroendocrine_pvals  ClusterC23_neuroendocrine_pvals_adj  \
# 495                         0.153543                             0.321771
# 496                         0.154256                             0.323104
# 497                         0.154319                             0.323209
# 498                         0.154603                             0.323717
# 499                         0.154817                             0.323964
#
#      ClusterC23_neuroendocrine_logfoldchanges ClusterC24_AT1_names  \
# 495                                  1.272359                  Cpq
# 496                                  1.564930               Pwwp3a
# 497                                  4.027638                Parva
# 498                                  7.486770               Rab3ip
# 499                                  2.735902               Ctnnd1
#
#      ClusterC24_AT1_pvals  ClusterC24_AT1_pvals_adj  \
# 495              0.293007                  0.409022
# 496              0.293323                  0.409022
# 497              0.293397                  0.409022
# 498              0.293821                  0.409022
# 499              0.294201                  0.409022
#
#      ClusterC24_AT1_logfoldchanges ClusterC25_Krt8_ADI_2_names  \
# 495                       3.042598                      Sdcbp2
# 496                       2.319582                       Cnih4
# 497                       1.190198                     Atp13a1
# 498                       2.088846                        Uba1
# 499                       1.395643                      Pcyox1
#
#      ClusterC25_Krt8_ADI_2_pvals  ClusterC25_Krt8_ADI_2_pvals_adj  \
# 495                     0.000873                         0.008770
# 496                     0.000866                         0.008713
# 497                     0.000903                         0.009031
# 498                     0.000884                         0.008877
# 499                     0.000906                         0.009041
#
#      ClusterC25_Krt8_ADI_2_logfoldchanges
# 495                              1.816639
# 496                              1.192521
# 497                              2.741052
# 498                              0.809803
# 499                              1.973412

# %%
cluster_marker.to_csv(result_folder+"EPITHELIAL_WNT_PCLS_cluster_marker_horizontally.csv")

# %% [markdown]
# #### export and layout clusters vertically

# %%
####
#### layout clusters vertically
####

cluster_marker=pd.DataFrame(columns = ['names', 'scores','logfoldchanges','pvals','pvals_adj','cluster'])
for group in groups:
    group_marker = pd.DataFrame(
    {key: result[key][group]
    for key in ['names', 'scores','logfoldchanges','pvals','pvals_adj']})
    group_marker['cluster'] = group
    cluster_marker=cluster_marker.append(group_marker)

# %%
cluster_marker.head()
# Out:
#      names     scores  logfoldchanges          pvals      pvals_adj cluster
# 0  mt-Rnr2  45.305584        1.852911  1.815628e-265  4.277256e-261      C0
# 1   Malat1  22.482218        1.667595   4.415912e-83   3.467668e-80      C0
# 2  mt-Rnr1  13.649235        1.311597   3.012854e-36   2.628771e-34      C0
# 3   Gm8995  11.309280        3.179454   4.782000e-26   2.213248e-24      C0
# 4   Akap12   8.949334        2.696359   1.176642e-17   2.828503e-16      C0

# %%
cluster_marker.tail()
# Out:
#        names    scores  logfoldchanges     pvals  pvals_adj         cluster
# 495   Sdcbp2  3.416520        1.816639  0.000873   0.008770  C25_Krt8_ADI_2
# 496    Cnih4  3.416517        1.192521  0.000866   0.008713  C25_Krt8_ADI_2
# 497  Atp13a1  3.408000        2.741052  0.000903   0.009031  C25_Krt8_ADI_2
# 498     Uba1  3.407791        0.809803  0.000884   0.008877  C25_Krt8_ADI_2
# 499   Pcyox1  3.405408        1.973412  0.000906   0.009041  C25_Krt8_ADI_2

# %%
cluster_marker.reset_index(drop = True,inplace=True) 
# drop = True, Do not try to insert index into dataframe columns

# %%
cluster_marker.to_csv(result_folder+"EPITHELIAL_WNT_PCLS_cluster_marker_vertically.csv")
